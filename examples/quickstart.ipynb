# %% [markdown]
# # Quickstart with PyMKF
# To have the right start let's check the lib is correctly installed and import it.
# check the version of the lib and the version of the dependencies.

# %%
# !pip install pymkf
# Out:
# Requirement already satisfied: pymkf in /home/tinix84/miniconda3/envs/icm/lib/python3.11/site-packages (0.9.12)

# %%
import PyMKF as pymkf

print(pymkf.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 import PyMKF as pymkf
# ----> 3 print(pymkf.__version__)
#
# AttributeError: module 'PyMKF' has no attribute '__version__'

# %%
# Get available core materials
core_materials = pymkf.get_core_materials()
print("Available core materials:", core_materials)
# Out:
# Available core materials: [{'bhCycle': None, 'coerciveForce': [{'magneticField': 14.0, 'magneticFluxDensity': 0.0, 'temperature': 100.0}, {'magneticField': 18.0, 'magneticFluxDensity': 0.0, 'temperature': 25.0}], 'curieTemperature': 220.0, 'density': 4800.0, 'family': '3C', 'heatCapacity': {'excludeMaximum': None, 'excludeMinimum': None, 'maximum': 800.0, 'minimum': 700.0, 'nominal': None}, 'heatConductivity': {'excludeMaximum': None, 'excludeMinimum': None, 'maximum': 7.0, 'minimum': 4.0, 'nominal': None}, 'manufacturerInfo': {'cost': None, 'datasheetUrl': 'https://www.ferroxcube.com/upload/media/product/file/MDS/3c90.pdf', 'family': None, 'name': 'Ferroxcube', 'orderCode': None, 'reference': None, 'status': None}, 'material': 'ferrite', 'materialComposition': None, 'name': '3C90', 'permeability': {'amplitude': None, 'complex': None, 'initial': [{'frequency': 10000.0, 'magneticFieldDcBias': None, 'magneticFluxDensityPeak': None, 'modifiers': None, 'temperature': -40.0, 'tolerance': None, 'value': 1416.09}, {'frequency': 10000.0, 'magneticFieldDcBias': None, 'magneticFluxDensityPeak': None, 'modifiers': None, 'temperature': -30.0, 'tolerance': None, 'value': 1502.95}, {'frequency': 10000.0, 'magneticFieldDcBias': None, 'magneticFluxDensityPeak': None, 'modifiers': None, 'temperature': -20.0, 'tolerance': None, 'value': 1634.22}, {'frequency': 10000.0, 'magneticFieldDcBias': None, 'magneticFluxDensityPeak': None, 'modifiers': None, 'temperature': -10.0, 'tolerance': None, 'value': 1764.42}, {'frequency': 10000.0, 'magneticFieldDcBias': None, 'magneticFluxDensityPeak': None, 'modifiers': None, 'temperature': 0.0, 'tolerance': None, 'value': 1908.2}, {'frequency': 10000.0, 'magneticFieldDcBias': None, 'magneticFluxDensityPeak': None, 'modifiers': None, 'temperature': 10.0, 'tolerance': None, 'value': 2074.27}, {'frequency': 10000.0, 'magneticFieldDcBias': None, 'magneticFluxDensityPeak': None, 'modifiers': None, 'temperature': 20.0, 'tolerance': None, 'value': 2249.28}, {'frequency': 10000.0, 'magneticFieldDcBias': None, 'magneticFluxDensityPeak': None, 'modifiers': None, 'temperature': 30.0, 'tolerance': None, 'value': 2478.38}, {'frequency': 10000.0, 'magneticFieldDcBias': None, 'magneticFluxDensityPeak': None, 'modifiers': None, 'temperature': 40.0, 'tolerance': None, 'value': 2705.02}, {'frequency': 10000.0, 'magneticFieldDcBias': None, 'magneticFluxDensityPeak': None, 'modifiers': None, 'temperature': 50.0, 'tolerance': None, 'value': 2936.08}, {'frequency': 10000.0, 'magneticFieldDcBias': None, 'magneticFluxDensityPeak': None, 'modifiers': None, 'temperature': 60.0, 'tolerance': None, 'value': 3180.75}, {'frequency': 10000.0, 'magneticFieldDcBias': None, 'magneticFluxDensityPeak': None, 'modifiers': None, 'temperature': 70.0, 'tolerance': None, 'value': 3424.97}, {'frequency': 10000.0, 'magneticFieldDcBias': None, 'magneticFluxDensityPeak': None, 'modifiers': None, 'temperature': 80.0, 'tolerance': None, 'value': 3622.12}, {'frequency': 10000.0, 'magneticFieldDcBias': None, 'magneticFluxDensityPeak': None, 'modifiers': None, 'temperature': 90.0, 'tolerance': None, 'value': 3810.62}, {'frequency': 10000.0, 'magneticFieldDcBias': None, 'magneticFluxDensityPeak': None, 'modifiers': None, 'temperature': 100.0, 'tolerance': None, 'value': 3963.47}, {'frequency': 10000.0, 'magneticFieldDcBias': None, 'magneticFluxDensityPeak': None, 'modifiers': None, 'temperature': 110.0, 'tolerance': None, 'value': 4053.94}, {'frequency': 10000.0, 'magneticFieldDcBias': None, 'magneticFluxDensityPeak': None, 'modifiers': None, 'temperature': 120.0, 'tolerance': None, 'value': 4003.41}, {'frequency': 10000.0, 'magneticFieldDcBias': None, 'magneticFluxDensityPeak': None, 'modifiers': None, 'temperature': 130.0, 'tolerance': None, 'value': 3940.25}, {'frequency': 10000.0, 'magneticFieldDcBias': None, 'magneticFluxDensityPeak': None, 'modifiers': None, 'temperature': 140.0, 'tolerance': None, 'value': 3899.6}, {'frequency': 10000.0, 'magneticFieldD ...

# %%
# Find a specific core shape
core_shape = pymkf.find_core_shape_by_name("E65/32/27")
print("Selected core shape:", core_shape)
# Out:
# Selected core shape: {'aliases': ['E 65/27'], 'dimensions': {'A': {'excludeMaximum': None, 'excludeMinimum': None, 'maximum': 0.0665, 'minimum': 0.0638, 'nominal': None}, 'B': {'excludeMaximum': None, 'excludeMinimum': None, 'maximum': 0.0328, 'minimum': 0.0322, 'nominal': None}, 'C': {'excludeMaximum': None, 'excludeMinimum': None, 'maximum': 0.0274, 'minimum': 0.0266, 'nominal': None}, 'D': {'excludeMaximum': None, 'excludeMinimum': None, 'maximum': 0.023, 'minimum': 0.0222, 'nominal': None}, 'E': {'excludeMaximum': None, 'excludeMinimum': None, 'maximum': 0.0457, 'minimum': 0.0442, 'nominal': None}, 'F': {'excludeMaximum': None, 'excludeMinimum': None, 'maximum': 0.02, 'minimum': 0.0193, 'nominal': None}}, 'family': 'e', 'familySubtype': None, 'magneticCircuit': 'open', 'name': 'E 65/32/27', 'type': 'standard'}
